# %% [markdown]
# # Import dependencies

# %%
import os
import cv2

# %% [markdown]
# # Read in image

# %%
img_path1 = os.path.join('data', 'images', 'portrait.jpg')

# %%
img_path1
# Out:
# 'data\\images\\portrait.jpg'

# %%
img1 = cv2.imread(img_path)

# %%
img1.shape
# Out:
# (6000, 4000, 3)

# %%
img_path2 = os.path.join('data', 'images', 'boy.jpg')

# %%
img_path2
# Out:
# 'data\\images\\boy.jpg'

# %%
img2 = cv2.imread(img_path2)

# %%
img2.shape
# Out:
# (5472, 3648, 3)

# %% [markdown]
# # Render Image

# %%
import matplotlib.pyplot as plt

# %%
#show image
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
#now the color in the original image and loaded image is different because of the order of reading
#of R, G, B is different in matplotlib and

# %%
recolor = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(recolor)

# %%
# Now creating a different image of the portrait image in gray
img1_gray = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img1_gray)

# %%
# Now creating a different image of the portrait image in gray
img2_hls = cv2.cvtColor(img2, cv2.COLOR_BGR2HLS)

# %%
plt.imshow(img2_hls)

# %% [markdown]
# # Writing the image

# %%
#testing===> this will create a root jpg folder as path is not defined
cv2.imwrite('img1_gray.jpg', img1_gray)
# Out:
# True

# %%
#now we will first define the output path then write out the image in a data->output folder
#first image
output_path = os.path.join('data', 'output', 'img1_gray.jpg')
cv2.imwrite(output_path, img1_gray)
# Out:
# True

# %%
#second image
output_path = os.path.join('data', 'output', 'img2_hls.jpg')
cv2.imwrite(output_path, img2_hls)
# Out:
# True
